# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import squarify
from pprint import pprint

# %%
df = pd.read_csv("../prices.csv")
df['Date'] = pd.to_datetime(df['Date'])
#df.set_index('Date', inplace=True)
df.head(5)
# Out:
#    SN            Commodity       Date Unit  Minimum  Maximum  Average
# 0   0   Tomato Big(Nepali) 2013-06-16   Kg     35.0     40.0     37.5
# 1   1  Tomato Small(Local) 2013-06-16   Kg     26.0     32.0     29.0
# 2   2           Potato Red 2013-06-16   Kg     20.0     21.0     20.5
# 3   3         Potato White 2013-06-16   Kg     15.0     16.0     15.5
# 4   4   Onion Dry (Indian) 2013-06-16   Kg     28.0     30.0     29.0

# %% [markdown]
# # Basic Data Information
# ## Summary Stats

# %%
print("Dataset Information:")
print(df.info())
print("\nDataset shape:", df.shape)
print("\nDataset summary:\n", df.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197161 entries, 0 to 197160
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SN         197161 non-null  int64
#  1   Commodity  197161 non-null  object
#  2   Date       197161 non-null  datetime64[ns]
#  3   Unit       197161 non-null  object
#  4   Minimum    197161 non-null  float64
#  5   Maximum    197161 non-null  float64
#  6   Average    197161 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 10.5+ MB
# None
#
# Dataset shape: (197161, 7)
#
# Dataset summary:
#                    SN        Minimum        Maximum        Average
# count  197161.000000  197161.000000  197161.000000  197161.000000
# mean    98580.000000      85.423938      94.161284      89.792611
# std     56915.622549      77.058896      82.375858      79.619003
# ...

# %% [markdown]
# ## Missing Values

# %%
print("Missing Values in Dataset:")
print(df.isnull().sum())
# Out:
# Missing Values in Dataset:
# SN           0
# Commodity    0
# Date         0
# Unit         0
# Minimum      0
# Maximum      0
# Average      0
# dtype: int64

# %% [markdown]
# # Price Exploration
# ## Overall Price Distributions
# The distributions for minimum, maximum, and average prices are quite similar. They are all right skewed, indicating that there are likely a few vegetables that are more expensive than the majority of other vegetables.

# %%
plt.figure(figsize=(14, 4))
for i, col in enumerate(['Minimum', 'Maximum', 'Average']):
    plt.subplot(1, 3, i+1)
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'{col} Price Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(data=df[['Minimum', 'Maximum', 'Average']])
plt.title('Boxplot of Price Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Extreme Price Analysis
# The most expensive vegetables are much, much more expensive than the majority of other vegetables.

# %%
top10 = df.sort_values(by='Average', ascending=False).drop_duplicates(subset='Commodity', keep='first').head(10)
bottom10 = df.sort_values(by='Average', ascending=True).drop_duplicates(subset='Commodity', keep='first').head(10)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.barplot(data=top10, x='Average', y='Commodity', palette='viridis')
plt.title('Top 10 Commodities by Average Price')
plt.xlabel('Average Price')

plt.subplot(1, 2, 2)
sns.barplot(data=bottom10, x='Average', y='Commodity', palette='viridis')
plt.title('Bottom 10 Commodities by Average Price')
plt.xlabel('Average Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Prices of a Few Vegetables Over Time
# Clearly, different vegetables have different price patterns.

# %%
asp_df = df[df["Commodity"] == "Asparagus"]

plt.figure(figsize=(12, 6))
plt.plot(asp_df.index, asp_df["Average"])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Asparagus Prices Over Time')
plt.tight_layout()
plt.show()

# %%
oka_df = df[df["Commodity"] == "Okara"]

plt.figure(figsize=(12, 6))
plt.plot(oka_df.index, oka_df["Average"])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Okara Prices Over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exploring Different Vegetables
# ## Unique Vegetables
# There are many different vegetables in our data, whose prices might behave differently. Additionally, the counts for the different vegetables are quite imbalanced.

# %%
print("Number of Unique Vegetables:", len(df["Commodity"].unique()))
# Out:
# Number of Unique Vegetables: 132

# %%
commodity_counts = df['Commodity'].value_counts()

plt.figure(figsize=(10, 6))
sns.histplot(commodity_counts, bins=30, kde=True)
plt.title('Distribution of Commodity Counts', fontsize=16)
plt.xlabel('Number of Occurrences')
plt.ylabel('Number of Commodities')
plt.show()

# %% [markdown]
# ## Cross Vegetable Relationships
# ### Correlations Among Prices for Different Vegetables
# There are vegetables that have prices correlated with other vegetables' prices.

# %%
pivot_df = df.pivot(index='Date', columns='Commodity', values='Average')
pivot_df_filled = pivot_df.interpolate(method='time')
pivot_df_filled = pivot_df_filled.ffill().bfill()
    
# Compute the correlation matrix among the commodities
commodity_corr = pivot_df.corr().fillna(0)

# Visualize the correlation matrix using a clustermap,
# which performs hierarchical clustering on the correlation matrix.
clustermap = sns.clustermap(commodity_corr, cmap='coolwarm', figsize=(14, 12))
clustermap.fig.suptitle("Clustermap of Vegetables' Average Price Correlations", y=1.05)
plt.show()
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ### Which Vegetables Might be Relevant for Predicting Each Vegetable's Price

# %%
threshold = 0.7

# map each vegetable to a set of vegetables with high correlation.
relevant_vegetables = {}
for veg in commodity_corr.index:
    # want vegetables with abs corr above threshold
    correlated = commodity_corr.loc[veg]
    relevant = set(correlated.index[correlated.abs() >= threshold])
    relevant_vegetables[veg] = relevant

print("Relevant Vegetables for Prediction (based on correlation threshold):")
pprint(relevant_vegetables)
# for veg, group in relevant_vegetables.items():
#     print(f"{veg}: {group}")
# Out:
# Relevant Vegetables for Prediction (based on correlation threshold):
# {'Apple(Fuji)': {'Apple(Fuji)',
#                  'Grapes(Black)',
#                  'Grapes(Green)',
#                  'Tomato Big(Indian)'},
#  'Apple(Jholey)': {'Apple(Jholey)',
#                    'Lemon',
#                    'Pear(Chinese)',
#                    'Strawberry',
#                    'Sweet Lime',
#                    'Turnip'},
#  'Arum': {'Arum', 'Musk Melon', 'Sweet Lime'},
#  'Asparagus': {'Asparagus',
#                'Cucumber(Hybrid)',
#                'Mandarin',
#                'Mango(Dushari)',
#                'Musk Melon',
#                'Potato Red(Mude)'},
#  'Bakula': {'Bakula',
#             'Mango(Calcutte)',
#             'Musk Melon',
#             'Sponge Gourd',
#             'Strawberry',
#             'Sweet Lime'},
#  'Bamboo Shoot': {'Bamboo Shoot',
#                   'Musk Melon',
#                   'Pear(Chinese)',
#                   'Potato Red(Mude)',
# ...
