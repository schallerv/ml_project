# %%
import tensorflow_hub as hub
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
def get_embeddings_old(texts):
    model_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    model = hub.load(model_url)
    embeddings = model(texts).numpy()
    embedding_dim = embeddings.shape[1]
    embedding_df = pd.DataFrame(embeddings, columns=[f"desc_emb_{i}" for i in range(embedding_dim)])
    return embedding_df
def get_embeddings(texts):
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(descriptions, batch_size=32, show_progress_bar=True)
    embedding_dim = embeddings.shape[1]
    embedding_df = pd.DataFrame(embeddings, columns=[f"desc_emb_{i}" for i in range(embedding_dim)])
    return embedding_df

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/Colab Notebooks/'
# Out:
# Mounted at /content/drive

# %%
print("reading games.csv")
df = pd.read_csv(file_path + "games.csv")
df = df.drop('Family', axis=1)
df = df.drop('ImagePath', axis=1)
df.dropna(subset=['Description'], inplace=True)
descriptions = df['Description'].tolist()
print("getting embeddings")
embeddings = get_embeddings(descriptions)
# save embeddings as csv
embeddings.to_csv("game_desc_embds.csv", index=False)
# Out:
# reading games.csv
# getting embeddings
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
embeddings.to_csv(file_path + "game_desc_embds.csv", index=False)
